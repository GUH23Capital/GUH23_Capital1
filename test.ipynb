# %%
# Generate Random Fraud
import requests
import json

url = "https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/77240408/create"

payload = ""
headers = {
  'Content-Type': 'application/json',
  'Version': '1.0',
  'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Y0N-kj6muDCmqg1F0QjUgCCsMwp7q4myBNverSFEqdzdDp90rRea78h6k4FS4JGmh5lg0802WQUHQBQDXc1e46LjlgSP_gW8oHOyjJB5IHauD-9BUb4YLZouY3zE79Iw3w0AldiLydjkjB2mk__QqQKZxUHBQJtWKV7tGvy7dpVNY_F_9KE9rFwSAu_eZZTueB3wvC1uyCoQTLxfQpIJ_gqjtX4OzakD1dOLI448FBbHhgOawfT2uT1tX75gqN-tYc_xGzhoNz2c6OsDdK5RLbj2nBx51V56yS2wbjwssQyrhqcyTjZ1IqQLUkwXxbu8UFKKZ0j8aklcKWlLefOKaA',
  'Cookie': 'AWSALB=HzPS2qrAw9ZO5XJhJwGKFA4E8QRcoIKsCnKZBAbe3JZfGIQZHbQHYbhRupGzd8I1pqR5xhsB8KVYR534BBYziZntH0OFotZIUjijScZiVLQ91kePpTqXUzzb941q; AWSALBCORS=HzPS2qrAw9ZO5XJhJwGKFA4E8QRcoIKsCnKZBAbe3JZfGIQZHbQHYbhRupGzd8I1pqR5xhsB8KVYR534BBYziZntH0OFotZIUjijScZiVLQ91kePpTqXUzzb941q'
}
for i in range(10):
    requests.request("POST", url, headers=headers, data=payload)

# %%
import requests
import json

url = "https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/transactions/accounts/77240408/transactions?status=eq:Declined"

payload = {}
headers = {
  'Content-Type': 'application/json',
  'Version': '1.0',
  'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Y0N-kj6muDCmqg1F0QjUgCCsMwp7q4myBNverSFEqdzdDp90rRea78h6k4FS4JGmh5lg0802WQUHQBQDXc1e46LjlgSP_gW8oHOyjJB5IHauD-9BUb4YLZouY3zE79Iw3w0AldiLydjkjB2mk__QqQKZxUHBQJtWKV7tGvy7dpVNY_F_9KE9rFwSAu_eZZTueB3wvC1uyCoQTLxfQpIJ_gqjtX4OzakD1dOLI448FBbHhgOawfT2uT1tX75gqN-tYc_xGzhoNz2c6OsDdK5RLbj2nBx51V56yS2wbjwssQyrhqcyTjZ1IqQLUkwXxbu8UFKKZ0j8aklcKWlLefOKaA',
  'Cookie': 'AWSALB=Bya5LrQ5sPBcsFxjFPLSKz5YpmWwJltDzC9y6w0E93Y+FjzRY7wOH2ab0ceoFGnJd+FjqhkJnFF5TA0fPpDg9XzSZhi4Pmde9WC1IuhWm8SRG8CA4/YjagU0qrkB; AWSALBCORS=Bya5LrQ5sPBcsFxjFPLSKz5YpmWwJltDzC9y6w0E93Y+FjzRY7wOH2ab0ceoFGnJd+FjqhkJnFF5TA0fPpDg9XzSZhi4Pmde9WC1IuhWm8SRG8CA4/YjagU0qrkB'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"Transactions":[{"transactionUUID":"be79e352-d067-4566-b564-a637ba57a74b","accountUUID":"77240408","merchantUUID":"13","merchant":{"name":"Masalas","category":"Shopping","description":"PCs, appliances, TVs at amazing prices!","pointOfSale":["Online","In-store"]},"amount":-282.58,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-07-04 06:23:17","emoji":"😭","latitude":52.874183712921806,"longitude":-1.8149089961677585,"status":"Declined","message":"Weekly wage of 282.58 (GBP, positive) from Masalas","pointOfSale":"Online"},{"transactionUUID":"ec545789-9fdb-442c-98de-0754bd3b6458","accountUUID":"77240408","merchantUUID":"15","merchant":{"name":"Streetlamps","category":"Shopping","description":"Where do they actually come from? From us.","pointOfSale":["Online","In-store"]},"amount":-249.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-09-04 09:59:14","emoji":"💩","latitude":53.57034930866327,"longitude":-2.197161275681077,"status":"Declined","message"
# ...

# %%
import csv
data = response.json()
# Extract relevant data
rows = []
for transaction in data["Transactions"]:
    latitude = transaction["latitude"]
    longitude = transaction["longitude"]
    timestamp = transaction["timestamp"]
    merchant_name = transaction["merchant"]["name"]
    rows.append([latitude, longitude, timestamp, merchant_name])

# Write data to a CSV file
with open("transactions.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Latitude", "Longitude", "Timestamp", "Merchant Name"])
    writer.writerows(rows)

print("Data has been written to transactions.csv")
# Out:
# Data has been written to transactions.csv

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Load data from the original CSV file
df = pd.read_csv("transactions.csv")

# Initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get location details for a given latitude and longitude
def get_location_details(lat, lon):
    location = geolocator.reverse(f"{lat},{lon}")
    address = location.raw['address']
    road = address.get('road', 'N/A')
    city = address.get('city', 'N/A')
    county = address.get('county', 'N/A')
    return road, city, county

# Add new columns for 'Road' and 'County' to the DataFrame
df['Road'], df['City'], df['County'] = zip(*df.apply(lambda row: get_location_details(row['Latitude'], row['Longitude']), axis=1))

# Save the updated DataFrame to a new CSV file with city information
df.to_csv("transactions_with_details.csv", index=False)

print("Data with city information saved to transactions_with_details.csv")
# Out:
# Data with city information saved to transactions_with_details.csv

# %%
import folium
import pandas as pd

# Load data from the CSV file
df = pd.read_csv("transactions_with_details.csv")

# Create a base map
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=6)



# Add markers for each latitude and longitude
for index, row in df.iterrows():
    popup_text = f"<b>{row['Merchant Name']}</b><br>Timestamp: {row['Timestamp']}<br>Road:{row['Road']}<br>City: {row['City']}<br>County: {row['County']}"
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_text, max_width=200),
    ).add_to(m)

# Save the map to an HTML file (optional)
m.save("map.html")

# Display the map in a Jupyter Notebook (if using Jupyter)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from geopy.geocoders import Nominatim

# Create a map centered on the city of York
geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.geocode("York, UK")
if location:
    map_center = [location.latitude, location.longitude]
else:
    # Fallback coordinates if geocoding fails
    map_center = [53.9590, -1.0815]

m = folium.Map(location=[map_center[0], map_center[1]], zoom_start=12)


# Add markers for points in the city of York
for index, row in df.iterrows():
    if isinstance(row['City'], str) and row['City'].lower() == 'york':
        popup_text = f"<b>{row['Merchant Name']}</b><br>Timestamp: {row['Timestamp']}<br>City: {row['City']}"
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=folium.Popup(popup_text, max_width=200),
            ).add_to(m)

# Save the map to an HTML file (optional)
# m.save("interactive_map_centered_on_York.html")

# Display the map in a Jupyter Notebook (if using Jupyter)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

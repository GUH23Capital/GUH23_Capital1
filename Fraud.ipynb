# %%
import csv

with open('accounts.csv', 'r') as file:
    csv_reader = csv.DictReader(file)
    data = list(csv_reader)

    
# df_list = list(df.index)
# print(df_list)

fraud_url_list = []
for row in data:
    accountid = row['accountId']
    url = ""
    url += "https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/"
    url+= accountid
    url += "/create"
    fraud_url_list.append(url)
    # print(url);
# print(url_list)

for x, row in enumerate(data):
    row['fraud_url'] = fraud_url_list[x]

with open('fraudlist.csv', 'w', newline='') as file:
    fieldnames = data[0].keys()
    csv_writer = csv.DictWriter(file, fieldnames=fieldnames)

    csv_writer.writeheader()
    csv_writer.writerows(data)

# %%
import requests
import json
import csv

rows = []
with open('fraudlist.csv', 'r') as file:
    csv_reader = csv.reader(file)

    next(csv_reader)

    # Specify the column index you want to read (0-indexed)
    column_index = 3  # Change this to the index of the column you want to read

    # Iterate through the rows and print the value of the specified column
    for row in csv_reader:
        url = row[column_index]
        print(url)
        payload = json.dumps({
          "quantity": "25"
        })
        headers = {
          'Content-Type': 'application/json',
          'Version': '1.0',
          'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Ewc9RP9qlXbQW_LPuJg8oX04ctkjnKqUOkVmjkLdw8N23ZdUJdH1BXtILSpIHx9Y5cF39Qs8gWyChMAmI3JVqpqBK7NoCs7yMNhXsxWwhrhNFxTYnLz0MdFB1KqVr1DHO1yNv14r-fM6Yw9ogNQjHHfHPtgEMjHKxF8NQaHYABD24yj9_N0_UxEI3KWCePnsxmMkXp0Oj5YIsXzialJRdQMDBCTN_gkLqSz_5tQqplqB6nF2bWZDEDNqHlRzqG3oHNS8cfnFYPOsANYQqK0y9st196oGKZWCEL-T3VHjB33kzzQUJxHan2mB83dCEcq4BG16xyaD7n84GAmkMktNEA',
          'Cookie': 'AWSALB=SPSdXltmeRP7i33+um6UG21a/lBhusxC9l1xupSia1f3ZSGtwVU7/WPOcOXONRMjBtcB75Z3O9qR7Ba0b6KMdT2eIE+KkyNypfRadbxkXYAEA6yA2qsqqB5aKnQh; AWSALBCORS=SPSdXltmeRP7i33+um6UG21a/lBhusxC9l1xupSia1f3ZSGtwVU7/WPOcOXONRMjBtcB75Z3O9qR7Ba0b6KMdT2eIE+KkyNypfRadbxkXYAEA6yA2qsqqB5aKnQh'
        }

        response = requests.request("POST", url, headers=headers, data=payload)

        print(response.text)
        data = response.json()

        for transaction in data["Transactions"]:
            accountid = transaction["accountUUID"]
            rows.append([accountid])
        # print(rows)

        # Write data to a CSV file
with open("frauds.csv", mode="w", newline="") as file:
  writer = csv.writer(file)
  writer.writerow(["frauds_id"])
  writer.writerows(rows)
# Out:
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/05047885/create
# {"Transactions":[{"transactionUUID":"3a5764fc-928f-474e-8baa-0cbec3e1ad6f","accountUUID":"05047885","merchantUUID":"10","merchant":{"name":"Car Stickers","category":"Auto & Transport","description":"High quality car racing stickers, that are used at races.","pointOfSale":["Online","In-store"]},"amount":-14.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-10-25 10:01:56","emoji":"🥰","latitude":52.616413549017416,"longitude":-2.5555752645230925,"status":"Successful","message":"Auto & Transport refund of 14.99 (GBP, positive) from Car Stickers","pointOfSale":"In-store"}],"newBalance":1200.31}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/40631196/create
# {"Transactions":[{"transactionUUID":"55e1b15c-230b-4f30-8c47-f53b4fd46c1c","accountUUID":"40631196","merchantUUID":"6","merchant":{"name":"Glamazon","category":"Shopping","description":"One stop shop for all your glamorous items.","pointOfSale":["Online","In-store"]},"amount":1293.99,"creditDebitIndicator":"Credit","currency":"CHF","timestamp":"2023-05-26 03:23:03","emoji":"🥰","latitude":47.00684716523438,"longitude":8.509429763945025,"status":"Successful","message":"Shopping purchase of 1293.99 (CHF, negative) at Glamazon","pointOfSale":"In-store"}],"newBalance":156.48}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/33827643/create
# {"Transactions":[{"transactionUUID":"4d6651fa-6dcc-42d5-84f9-a2a93807dd2c","accountUUID":"33827643","merchantUUID":"8","merchant":{"name":"Fact News","category":"Education","description":"News with only facts","pointOfSale":["Online","In-store"]},"amount":-40.26,"creditDebitIndicator":"Debit","currency":"EUR","timestamp":"2023-10-23 13:38:33","emoji":"🥰","latitude":47.21825663495527,"longitude":7.467021709865981,"status":"Successful","message":"Education refund of 40.26 (EUR, positive) from Fact News","pointOfSale":"Online"}],"newBalance":1194.32}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/64889502/create
# {"Transactions":[{"transactionUUID":"6050a760-0b00-4894-9522-576800c06224","accountUUID":"64889502","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":-29.99,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-09-19 04:28:04","emoji":"💩","latitude":54.71402878752796,"longitude":-2.0182791133985916,"status":"Declined","message":"Entertainment refund of 29.99 (GBP, positive) from Vapour","pointOfSale":"Online"},{"transactionUUID":"e90b4dc7-6e87-4576-a994-e5b90831f6e8","accountUUID":"64889502","merchantUUID":"1","merchant":{"name":"Blahbucks","category":"Food & Dining","description":"Supplying all your coffee needs","pointOfSale":["In-store"]},"amount":-241.98,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-05-18 14:28:23","emoji":"😭","latitude":53.18967792083622,"longitude":-1.2601769765307154,"status":"Declined","message":"Weekly wage of 241.98 (GBP, positive) from Blahbucks","pointOfSale":"In-store"},{"transactionUUID":"e956d438-152c-4021-8be7-1c6d9072784c","accountUUID":"64889502","merchantUUID":"10","merchant":{"name":"Car Stickers","category":"Auto & Transport","description":"High quality car racing stickers, that are used at races.","pointOfSale":["Online","In-store"]},"amount":167.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-06-12 03:24:15","emoji":"😭","latitude":54.514868184043436,"longitude":-2.0971033024530956,"status":"Declined","message":"Auto & Transport purchase of 167.99 (GBP, negative) at Car Stickers","pointOfSale":"Online"},{"transactionUUID":"4d04ef0d-14f6-4122-b63f-be6f4d9ed412","accountUUID":"64889502","merchantUUID":"6","merchant":{"name":"Glamazon","category":"Shopping","description":"One stop shop for all your glamorous items.","pointOfSale":["Online","In-store"]},"amount":37.68,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-08-28 11:46:38","emoji":"😭","latitude":52.1760822362049,"longitude":-2.603068200210753,"status":"Declined","message":"Shopping purchase of 37.68 (GBP, negative) at Glamazon","pointOfSale":"Online"},{"transactionUUID":"e1555e3d-5de8-4e2b-9f67-9691aca26efa","accountUUID":"64889502","merchantUUID":"4","merchant":{"name":"Pear Retail","category":"Shopping","description":"Computers, phones and other shiny electrical things","pointOfSale":["Online","In-store"]},"amount":23.4,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-07-12 07:27:51","emoji":"😭","latitude":54.15427988530847,"longitude":-2.062750278017812,"status":"Declined","message":"Shopping purchase of 23.4 (GBP, negative) at Pear Retail","pointOfSale":"Online"},{"transactionUUID":"d2101147-8a65-4127-a874-ca987e97701e","accountUUID":"64889502","merchantUUID":"12","merchant":{"name":"CatShoes","category":"Personal Care","description":"Purrfectly fitted moccasins for your kittens.","pointOfSale":["Online"]},"amount":8.24,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-07-03 05:08:02","emoji":"😭","latitude":53.53158788717034,"longitude":-0.8228822844268708,"status":"Declined","message":"Personal Care purchase of 8.24 (GBP, negative) at CatShoes","pointOfSale":"Online"},{"transactionUUID":"c20d19b9-66ad-4d6c-83a3-9abadb547d4d","accountUUID":"64889502","merchantUUID":"14","merchant":{"name":"Boardwalk Games","category":"Entertainment","description":"Events company specialising in board games near the sea.","pointOfSale":["Online"]},"amount":12.99,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-05-27 19:38:03","emoji":"😭","latitude":53.865123744491044,"longitude":-1.7478161321321874,"status":"Declined","message":"Entertainment purchase of 12.99 (GBP, negative) at Boardwalk Games","pointOfSale":"Online"},{"transactionUUID":"ef36338f-5f0c-4c35-b41f-7424cc197960","accountUUID":"64889502","merchantUUID":"11","merchant":{"name":"McFairbank","category":"Food & Dining","description":"Fast food - but with interest.","p ...
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/63408301/create
# {"Transactions":[{"transactionUUID":"75548475-975d-4e0f-9839-539a9eff1d03","accountUUID":"63408301","merchantUUID":"4","merchant":{"name":"Pear Retail","category":"Shopping","description":"Computers, phones and other shiny electrical things","pointOfSale":["Online","In-store"]},"amount":0.91,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-10-27 18:04:31","emoji":"💸","latitude":55.53637000766195,"longitude":-3.7228258585927905,"status":"Successful","message":"Shopping purchase of 0.91 (GBP, negative) at Pear Retail","pointOfSale":"In-store"}],"newBalance":1803.59}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/33797779/create
# {"Transactions":[{"transactionUUID":"b34a61ac-8d92-4338-b33a-03b43ce7afb2","accountUUID":"33797779","merchantUUID":"8","merchant":{"name":"Fact News","category":"Education","description":"News with only facts","pointOfSale":["Online","In-store"]},"amount":9.99,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-05-31 05:54:59","emoji":"💩","latitude":54.09168914939409,"longitude":-2.8639518596584126,"status":"Declined","message":"Education purchase of 9.99 (GBP, negative) at Fact News","pointOfSale":"In-store"},{"transactionUUID":"b3182c19-4162-412b-8a60-5dd034d55081","accountUUID":"33797779","merchantUUID":"14","merchant":{"name":"Boardwalk Games","category":"Entertainment","description":"Events company specialising in board games near the sea.","pointOfSale":["Online"]},"amount":59.99,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-06-02 02:21:00","emoji":"💩","latitude":54.319103975753244,"longitude":-2.527805924505771,"status":"Declined","message":"Entertainment purchase of 59.99 (GBP, negative) at Boardwalk Games","pointOfSale":"Online"},{"transactionUUID":"73de0d46-3a33-4eb2-a667-645f778e726a","accountUUID":"33797779","merchantUUID":"3","merchant":{"name":"Xenoxx Corporation","category":"Entertainment","description":"Your local, friendly megacorporation","pointOfSale":["Online","In-store"]},"amount":-33.14,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-09-25 10:01:19","emoji":"😭","latitude":53.9447554311099,"longitude":-2.76819402653065,"status":"Declined","message":"Entertainment refund of 33.14 (GBP, positive) from Xenoxx Corporation","pointOfSale":"Online"},{"transactionUUID":"1a7c8fee-917f-4a1e-9655-2731070922e8","accountUUID":"33797779","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":-15.69,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-10-03 13:41:04","emoji":"💩","latitude":53.363637716064325,"longitude":-3.115362737569144,"status":"Declined","message":"Entertainment refund of 15.69 (GBP, positive) from Vapour","pointOfSale":"Online"}],"newBalance":1504.67}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/52241919/create
# {"Transactions":[{"transactionUUID":"2a6054ce-8943-4d69-ba54-53004594144b","accountUUID":"52241919","merchantUUID":"5","merchant":{"name":"Capital Two","category":"Bills & Utilities","description":"Credit Card Company","pointOfSale":["Online"]},"amount":21.99,"creditDebitIndicator":"Credit","currency":"JPY","timestamp":"2023-08-10 15:56:59","emoji":"🤑","latitude":37.32890634450935,"longitude":139.56782700048637,"status":"Successful","message":"Bills & Utilities purchase of 21.99 (JPY, negative) at Capital Two","pointOfSale":"Online"}],"newBalance":501.72}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/40826542/create
# {"Transactions":[{"transactionUUID":"a2ca6ba6-16b7-4764-acba-38064b053014","accountUUID":"40826542","merchantUUID":"15","merchant":{"name":"Streetlamps","category":"Shopping","description":"Where do they actually come from? From us.","pointOfSale":["Online","In-store"]},"amount":-4.62,"creditDebitIndicator":"Debit","currency":"USD","timestamp":"2023-08-01 03:56:21","emoji":"🤑","latitude":39.93497224151295,"longitude":-101.23188228655127,"status":"Successful","message":"Shopping refund of 4.62 (USD, positive) from Streetlamps","pointOfSale":"In-store"}],"newBalance":1627.14}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/38085602/create
# {"Transactions":[{"transactionUUID":"3d767fb4-a6be-44c5-94be-b015998a04d6","accountUUID":"38085602","merchantUUID":"4","merchant":{"name":"Pear Retail","category":"Shopping","description":"Computers, phones and other shiny electrical things","pointOfSale":["Online","In-store"]},"amount":-1.62,"creditDebitIndicator":"Debit","currency":"CAD","timestamp":"2023-10-13 12:44:43","emoji":"🥰","latitude":61.22778248238045,"longitude":-107.6225861614252,"status":"Successful","message":"Shopping refund of 1.62 (CAD, positive) from Pear Retail","pointOfSale":"Online"}],"newBalance":674.83}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/41460004/create
# {"Transactions":[{"transactionUUID":"c817d865-d729-40bc-8741-5c09228053ac","accountUUID":"41460004","merchantUUID":"3","merchant":{"name":"Xenoxx Corporation","category":"Entertainment","description":"Your local, friendly megacorporation","pointOfSale":["Online","In-store"]},"amount":-169.99,"creditDebitIndicator":"Debit","currency":"AUD","timestamp":"2023-06-25 11:03:41","emoji":"🥰","latitude":-30.95724719085682,"longitude":147.7525943618892,"status":"Successful","message":"Weekly wage of 169.99 (AUD, positive) from Xenoxx Corporation","pointOfSale":"In-store"}],"newBalance":794.33}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/25397554/create
# {"Transactions":[{"transactionUUID":"5f745b1d-33cf-4db0-838c-aa72c3b24d24","accountUUID":"25397554","merchantUUID":"15","merchant":{"name":"Streetlamps","category":"Shopping","description":"Where do they actually come from? From us.","pointOfSale":["Online","In-store"]},"amount":-183.99,"creditDebitIndicator":"Credit","currency":"CAD","timestamp":"2023-07-04 00:08:45","emoji":"💸","latitude":62.43389094046913,"longitude":-99.21600038447882,"status":"Successful","message":"Weekly wage of 183.99 (CAD, positive) from Streetlamps","pointOfSale":"Online"}],"newBalance":1553.42}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/53225778/create
# {"Transactions":[{"transactionUUID":"2ba7756a-b638-401b-9743-7831950e8fef","accountUUID":"53225778","merchantUUID":"12","merchant":{"name":"CatShoes","category":"Personal Care","description":"Purrfectly fitted moccasins for your kittens.","pointOfSale":["Online"]},"amount":-59.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-07-29 22:00:26","emoji":"💸","latitude":53.41875282223457,"longitude":-2.801566289353179,"status":"Successful","message":"Personal Care refund of 59.99 (GBP, positive) from CatShoes","pointOfSale":"Online"}],"newBalance":995.07}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/96585083/create
# {"Transactions":[{"transactionUUID":"be15b900-8997-4bf8-b31b-636d89668c5d","accountUUID":"96585083","merchantUUID":"7","merchant":{"name":"Trees Trees Trees","category":"Education","description":"High quality readings, reports, documentaries on one topic: trees.","pointOfSale":["Online"]},"amount":-7.99,"creditDebitIndicator":"Credit","currency":"INR","timestamp":"2023-05-16 16:22:37","emoji":"🤑","latitude":17.994509060942477,"longitude":80.17969951716955,"status":"Successful","message":"Education refund of 7.99 (INR, positive) from Trees Trees Trees","pointOfSale":"Online"}],"newBalance":567.85}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/13965130/create
# {"Transactions":[{"transactionUUID":"c40c0fb1-76df-4bbf-96c4-d63ab3e6c1ed","accountUUID":"13965130","merchantUUID":"11","merchant":{"name":"McFairbank","category":"Food & Dining","description":"Fast food - but with interest.","pointOfSale":["Online","In-store"]},"amount":32.01,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-08-04 00:58:41","emoji":"🤑","latitude":54.7804296757716,"longitude":-2.156490802848238,"status":"Successful","message":"Food & Dining purchase of 32.01 (GBP, negative) at McFairbank","pointOfSale":"In-store"}],"newBalance":1945.36}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/55332420/create
# {"Transactions":[{"transactionUUID":"4e9e1068-3985-49c3-a308-e4082ea8e27b","accountUUID":"55332420","merchantUUID":"9","merchant":{"name":"MoonHog","category":"Gifts & Donations","description":"Beautiful personal cards for every occasion.","pointOfSale":["Online"]},"amount":59.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-05-15 02:22:32","emoji":"🤑","latitude":53.22964512830265,"longitude":-3.2729076156489088,"status":"Successful","message":"Gifts & Donations purchase of 59.99 (GBP, negative) at MoonHog","pointOfSale":"Online"}],"newBalance":1746}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/61259923/create
# {"Transactions":[{"transactionUUID":"3d47983b-4fe2-4cf0-8725-79ec23cc42f7","accountUUID":"61259923","merchantUUID":"5","merchant":{"name":"Capital Two","category":"Bills & Utilities","description":"Credit Card Company","pointOfSale":["Online"]},"amount":26.51,"creditDebitIndicator":"Debit","currency":"USD","timestamp":"2023-10-10 14:26:13","emoji":"🤑","latitude":31.97314629433756,"longitude":-90.55393630881483,"status":"Successful","message":"Bills & Utilities purchase of 26.51 (USD, negative) at Capital Two","pointOfSale":"Online"}],"newBalance":1907.3}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/75500676/create
# {"Transactions":[{"transactionUUID":"916407a5-1f8a-495d-a74f-0a88ac12937e","accountUUID":"75500676","merchantUUID":"3","merchant":{"name":"Xenoxx Corporation","category":"Entertainment","description":"Your local, friendly megacorporation","pointOfSale":["Online","In-store"]},"amount":769.99,"creditDebitIndicator":"Debit","currency":"MYR","timestamp":"2023-08-24 13:27:59","emoji":"🤑","latitude":4.3888116842212055,"longitude":101.45478216096458,"status":"Successful","message":"Entertainment purchase of 769.99 (MYR, negative) at Xenoxx Corporation","pointOfSale":"In-store"}],"newBalance":2098.89}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/12615827/create
# {"Transactions":[{"transactionUUID":"0af4072e-d5a2-4138-9fb0-dbb8832dcdb8","accountUUID":"12615827","merchantUUID":"5","merchant":{"name":"Capital Two","category":"Bills & Utilities","description":"Credit Card Company","pointOfSale":["Online"]},"amount":22.52,"creditDebitIndicator":"Debit","currency":"JPY","timestamp":"2023-06-02 12:44:20","emoji":"💸","latitude":37.45749178634956,"longitude":140.02412851318329,"status":"Successful","message":"Bills & Utilities purchase of 22.52 (JPY, negative) at Capital Two","pointOfSale":"Online"}],"newBalance":720.48}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/62262067/create
# {"Transactions":[{"transactionUUID":"d5a75748-2139-440e-baef-c295d8242e90","accountUUID":"62262067","merchantUUID":"13","merchant":{"name":"Masalas","category":"Shopping","description":"PCs, appliances, TVs at amazing prices!","pointOfSale":["Online","In-store"]},"amount":85.61,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-06-07 18:54:29","emoji":"🥰","latitude":54.99886008094115,"longitude":-3.5422300032226257,"status":"Successful","message":"Shopping purchase of 85.61 (GBP, negative) at Masalas","pointOfSale":"Online"}],"newBalance":1770.86}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/66601193/create
# {"Transactions":[{"transactionUUID":"528aa9ea-8403-4a1e-a313-4b8c88425d32","accountUUID":"66601193","merchantUUID":"3","merchant":{"name":"Xenoxx Corporation","category":"Entertainment","description":"Your local, friendly megacorporation","pointOfSale":["Online","In-store"]},"amount":35.99,"creditDebitIndicator":"Credit","currency":"CNY","timestamp":"2023-07-18 18:53:27","emoji":"💸","latitude":32.44209187701321,"longitude":108.31219985458154,"status":"Successful","message":"Entertainment purchase of 35.99 (CNY, negative) at Xenoxx Corporation","pointOfSale":"In-store"}],"newBalance":1424.96}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/03113662/create
# {"Transactions":[{"transactionUUID":"4bf7abb0-d50f-40b9-98ac-2877ecdcc5af","accountUUID":"03113662","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":-29.81,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-05-19 12:41:08","emoji":"💩","latitude":54.334983896842864,"longitude":-2.2489483832026176,"status":"Declined","message":"Entertainment refund of 29.81 (GBP, positive) from Vapour","pointOfSale":"Online"},{"transactionUUID":"6f6215ba-c974-4790-8ed5-59484128d019","accountUUID":"03113662","merchantUUID":"10","merchant":{"name":"Car Stickers","category":"Auto & Transport","description":"High quality car racing stickers, that are used at races.","pointOfSale":["Online","In-store"]},"amount":130.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-06-17 02:08:01","emoji":"😭","latitude":53.14759931659427,"longitude":-3.0174930698373035,"status":"Declined","message":"Auto & Transport purchase of 130.99 (GBP, negative) at Car Stickers","pointOfSale":"Online"},{"transactionUUID":"65a89645-7d4b-493b-89a8-d735dac6e121","accountUUID":"03113662","merchantUUID":"1","merchant":{"name":"Blahbucks","category":"Food & Dining","description":"Supplying all your coffee needs","pointOfSale":["In-store"]},"amount":-79.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-10-28 06:40:19","emoji":"💩","latitude":54.156142559299056,"longitude":-2.7267084596363027,"status":"Declined","message":"Food & Dining refund of 79.99 (GBP, positive) from Blahbucks","pointOfSale":"In-store"},{"transactionUUID":"a3dfd73e-a035-47eb-ad75-145aaff95777","accountUUID":"03113662","merchantUUID":"4","merchant":{"name":"Pear Retail","category":"Shopping","description":"Computers, phones and other shiny electrical things","pointOfSale":["Online","In-store"]},"amount":9.99,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-08-03 14:46:07","emoji":"😭","latitude":53.64228704914916,"longitude":-0.6733504147142364,"status":"Declined","message":"Shopping purchase of 9.99 (GBP, negative) at Pear Retail","pointOfSale":"In-store"},{"transactionUUID":"a076c310-5f2b-4b39-b05f-5b820b443fe9","accountUUID":"03113662","merchantUUID":"10","merchant":{"name":"Car Stickers","category":"Auto & Transport","description":"High quality car racing stickers, that are used at races.","pointOfSale":["Online","In-store"]},"amount":29.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-05-18 13:21:04","emoji":"😭","latitude":54.55188207561201,"longitude":-1.2924428118395426,"status":"Declined","message":"Auto & Transport purchase of 29.99 (GBP, negative) at Car Stickers","pointOfSale":"In-store"},{"transactionUUID":"414433b4-be89-433e-a2f9-307fe056ecb8","accountUUID":"03113662","merchantUUID":"10","merchant":{"name":"Car Stickers","category":"Auto & Transport","description":"High quality car racing stickers, that are used at races.","pointOfSale":["Online","In-store"]},"amount":-834.22,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-09-21 08:21:07","emoji":"😭","latitude":54.540254400845534,"longitude":-1.6626932388802185,"status":"Declined","message":"Monthly salary of 834.22 (GBP, positive) from Car Stickers","pointOfSale":"Online"},{"transactionUUID":"0d9c4cb0-ee98-4794-8493-2db63ae3fcf1","accountUUID":"03113662","merchantUUID":"4","merchant":{"name":"Pear Retail","category":"Shopping","description":"Computers, phones and other shiny electrical things","pointOfSale":["Online","In-store"]},"amount":323.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-05-31 14:28:29","emoji":"😭","latitude":54.73981028644124,"longitude":-1.4113283726678703,"status":"Declined","message":"Shopping purchase of 323.99 (GBP, negative) at Pear Retail","pointOfSale":"In-store"},{"transactionUUID":"a0ad6135-d7f0-49aa-a72f-46bd0b32a03d","accountUUID":"03113662","merchantUUID":"1","merchant":{"name":"Blahbucks","c ...
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/49273629/create
# {"Transactions":[{"transactionUUID":"1bcae255-ccbd-431f-902d-f7d8dc21b2f2","accountUUID":"49273629","merchantUUID":"11","merchant":{"name":"McFairbank","category":"Food & Dining","description":"Fast food - but with interest.","pointOfSale":["Online","In-store"]},"amount":-9.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-05-15 09:13:32","emoji":"🥰","latitude":53.26761044642697,"longitude":-0.9702855001959434,"status":"Successful","message":"Food & Dining refund of 9.99 (GBP, positive) from McFairbank","pointOfSale":"Online"}],"newBalance":503.42}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/21895097/create
# {"Transactions":[{"transactionUUID":"fac15d11-5d5d-41d9-81e5-b723817bd666","accountUUID":"21895097","merchantUUID":"5","merchant":{"name":"Capital Two","category":"Bills & Utilities","description":"Credit Card Company","pointOfSale":["Online"]},"amount":25.32,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-06-16 22:15:36","emoji":"💩","latitude":55.5094422333532,"longitude":-3.481096771388671,"status":"Declined","message":"Bills & Utilities purchase of 25.32 (GBP, negative) at Capital Two","pointOfSale":"Online"},{"transactionUUID":"5c4f2b79-7f6d-4062-87e0-c5f0d354dcb7","accountUUID":"21895097","merchantUUID":"13","merchant":{"name":"Masalas","category":"Shopping","description":"PCs, appliances, TVs at amazing prices!","pointOfSale":["Online","In-store"]},"amount":29.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-06-13 19:30:49","emoji":"😭","latitude":52.113041963087106,"longitude":-2.3517300207614356,"status":"Declined","message":"Shopping purchase of 29.99 (GBP, negative) at Masalas","pointOfSale":"In-store"},{"transactionUUID":"ad55f6f6-b00c-4690-99b1-73140faa1148","accountUUID":"21895097","merchantUUID":"3","merchant":{"name":"Xenoxx Corporation","category":"Entertainment","description":"Your local, friendly megacorporation","pointOfSale":["Online","In-store"]},"amount":-25.79,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-09-13 23:27:40","emoji":"😭","latitude":56.19104106100809,"longitude":-3.275016644381754,"status":"Declined","message":"Entertainment refund of 25.79 (GBP, positive) from Xenoxx Corporation","pointOfSale":"In-store"},{"transactionUUID":"3a62f758-6908-4a89-be5f-9add5e7a1fc1","accountUUID":"21895097","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":56.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-08-27 21:10:06","emoji":"💩","latitude":54.676492587798336,"longitude":-2.514296005001487,"status":"Declined","message":"Entertainment purchase of 56.99 (GBP, negative) at Vapour","pointOfSale":"Online"},{"transactionUUID":"81bcf332-cc04-4108-8d2c-730f215c7952","accountUUID":"21895097","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":12.79,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-09-24 19:39:55","emoji":"💩","latitude":52.94789052260773,"longitude":-2.2664420829245033,"status":"Declined","message":"Entertainment purchase of 12.79 (GBP, negative) at Vapour","pointOfSale":"Online"},{"transactionUUID":"249100cc-900d-48aa-a2b1-1b4b52f811c1","accountUUID":"21895097","merchantUUID":"7","merchant":{"name":"Trees Trees Trees","category":"Education","description":"High quality readings, reports, documentaries on one topic: trees.","pointOfSale":["Online"]},"amount":23.77,"creditDebitIndicator":"Credit","currency":"GBP","timestamp":"2023-10-22 23:36:33","emoji":"😭","latitude":54.20032168491057,"longitude":-1.5329949227465862,"status":"Declined","message":"Education purchase of 23.77 (GBP, negative) at Trees Trees Trees","pointOfSale":"Online"},{"transactionUUID":"16b18281-80dc-405b-9879-b3eccb977e7d","accountUUID":"21895097","merchantUUID":"9","merchant":{"name":"MoonHog","category":"Gifts & Donations","description":"Beautiful personal cards for every occasion.","pointOfSale":["Online"]},"amount":-63.73,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-07-31 10:03:00","emoji":"😭","latitude":53.954451451783214,"longitude":-3.08257176131512,"status":"Declined","message":"Gifts & Donations refund of 63.73 (GBP, positive) from MoonHog","pointOfSale":"Online"}],"newBalance":1344.94}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/78329380/create
# {"Transactions":[{"transactionUUID":"cd81d9de-8cfe-44bc-ab3f-8d9477048690","accountUUID":"78329380","merchantUUID":"2","merchant":{"name":"Vapour","category":"Entertainment","description":"The World's #1 Game Store","pointOfSale":["Online"]},"amount":29.99,"creditDebitIndicator":"Debit","currency":"GBP","timestamp":"2023-07-08 21:26:35","emoji":"🤑","latitude":54.75657602013356,"longitude":-2.381459507592051,"status":"Successful","message":"Entertainment purchase of 29.99 (GBP, negative) at Vapour","pointOfSale":"Online"}],"newBalance":1917.07}
# https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/fraud/transactions/accounts/96163884/create
# {"Transactions":[{"transactionUUID":"2a5ec553-1498-4db3-8f36-2d14371ff946","accountUUID":"96163884","merchantUUID":"14","merchant":{"name":"Boardwalk Games","category":"Entertainment","description":"Events company specialising in board games near the sea.","pointOfSale":["Online"]},"amount":16.31,"creditDebitIndicator":"Debit","currency":"JPY","timestamp":"2023-08-31 07:54:03","emoji":"💸","latitude":37.614358402005934,"longitude":140.14850144893282,"status":"Successful","message":"Entertainment purchase of 16.31 (JPY, negative) at Boardwalk Games","pointOfSale":"Online"}],"newBalance":447.77}

# %%
# rows = []
# for transaction in data["Transactions"]:
#     accountid = transaction["accountUUID"]
#     rows.append([accountid])

# # Write data to a CSV file
# with open("frauds.csv", mode="w", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerow(["frauds_id"])
#     writer.writerows(rows)

# %%
import requests
import json

url = "https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/accounts"

payload = {}
headers = {
  'Content-Type': 'application/json',
  'Version': '1.0',
  'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Ewc9RP9qlXbQW_LPuJg8oX04ctkjnKqUOkVmjkLdw8N23ZdUJdH1BXtILSpIHx9Y5cF39Qs8gWyChMAmI3JVqpqBK7NoCs7yMNhXsxWwhrhNFxTYnLz0MdFB1KqVr1DHO1yNv14r-fM6Yw9ogNQjHHfHPtgEMjHKxF8NQaHYABD24yj9_N0_UxEI3KWCePnsxmMkXp0Oj5YIsXzialJRdQMDBCTN_gkLqSz_5tQqplqB6nF2bWZDEDNqHlRzqG3oHNS8cfnFYPOsANYQqK0y9st196oGKZWCEL-T3VHjB33kzzQUJxHan2mB83dCEcq4BG16xyaD7n84GAmkMktNEA',
  'Cookie': 'AWSALB=CWTxdH+906Q87QXSUvqboEUdyOi7eOTs2B+AsvjdP9OfNfJM0Htd+zCgxphTp7BzIftXMdCF9pQI0DefC/9K3JYmaAyuypad7+yA3ekXXfFx+gm5LbfMJjwnq74E; AWSALBCORS=CWTxdH+906Q87QXSUvqboEUdyOi7eOTs2B+AsvjdP9OfNfJM0Htd+zCgxphTp7BzIftXMdCF9pQI0DefC/9K3JYmaAyuypad7+yA3ekXXfFx+gm5LbfMJjwnq74E'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"Accounts":[{"creditScore":"660","firstname":"Manie","liveBalance":"true","lastname":"Glover","accountId":"11657178","phoneNumber":"+44836778675","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"1354.18","creditLimit":"927","uci":"178463","riskScore":"81","state":"open","currencyCode":"GBP","productType":"Credit","email":"Manie.Glover@freeemailservice.com","homeAddress":"17 South Road, Sutton, United Kingdom"},{"creditScore":"42","firstname":"Trish","liveBalance":"true","lastname":"Kunde","accountId":"78182213","phoneNumber":"+44814551156","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"769.29","creditLimit":"0","uci":"752389","riskScore":"49","state":"open","currencyCode":"GBP","productType":"Debit","email":"Trish.Kunde@emailshere.com","homeAddress":"29 North Avenue, Winchester, United Kingdom"},{"creditScore":"272","firstname":"Luis","liveBalance":"true","lastname":"Wolff","accountId":"48350000","phoneNumber":"+44863541077","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"752.27","creditLimit":"549","uci":"035412","riskScore":"19","state":"open","currencyCode":"GBP","productType":"Credit","email":"Luis.Wolff@freeemailservice.com","homeAddress":"94 Hill Close, Clermont-Ferrand, France"},{"creditScore":"34","firstname":"Britt","liveBalance":"true","lastname":"Bednar","accountId":"43554718","phoneNumber":"+44886327597","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"1176.03","creditLimit":"950","uci":"416942","riskScore":"73","state":"open","currencyCode":"CAD","productType":"Credit","email":"Britt.Bednar@realemail.com","homeAddress":"11 Chapel Drive, Preston, United Kingdom"},{"creditScore":"104","firstname":"Beatrice","liveBalance":"true","lastname":"VonRueden","accountId":"58345709","phoneNumber":"+44880929083","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"-29518.37","creditLimit":"0","uci":"468282","riskScore":"56","state":"open","currencyCode":"GBP","productType":"Debit","email":"Beatrice.VonRueden@emailprovider.com","homeAddress":"29 Park Street, Giffnock, United Kingdom"},{"creditScore":"55","firstname":"Christene","liveBalance":"true","lastname":"Tillman","accountId":"51062315","phoneNumber":"+44817198090","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"1663.24","creditLimit":"0","uci":"208735","riskScore":"38","state":"open","currencyCode":"GBP","productType":"Debit","email":"Christene.Tillman@sendemails.com","homeAddress":"15 Castle Way, Bournemouth, United Kingdom"},{"creditScore":"617","firstname":"Wanita","liveBalance":"true","lastname":"Beahan","accountId":"21227249","phoneNumber":"+44833715452","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"2083.02","creditLimit":"0","uci":"072035","riskScore":"45","state":"open","currencyCode":"GBP","productType":"Debit","email":"Wanita.Beahan@mailbox.co.uk","homeAddress":"55 Kings Drive, Halmstad, Sweden"},{"creditScore":"548","firstname":"Gustavo","liveBalance":"true","lastname":"Carroll","accountId":"96267302","phoneNumber":"+44817452437","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"750.08","creditLimit":"643","uci":"005610","riskScore":"47","state":"open","currencyCode":"EUR","productType":"Credit","email":"Gustavo.Carroll@freeemailservice.com","homeAddress":"52 Manor Close, Kimmirut, Canada"},{"creditScore":"666","firstname":"Isa","liveBalance":"true","lastname":"Ledner","accountId":"99840338","phoneNumber":"+44896365860","developerId":"bae438c7921a377196ddc065161198991cd7b1b23463de310b9eb59a551e750d","balance":"1119.19","creditLimit":"950","uci":"392180","riskScore":"29","state":"open","currencyCode":"GBP","productType":"Credit","email":"Isa.Ledner@emailprovider.com","homeAddress":"35 Mill Lane, Cambridge, United Kingdom"} ...

# %%
accountList = []

json_data = json.loads(response.text)

accounts = json_data.get("Accounts")
for x in range(len(accounts)):
    accountList.append(accounts[x]['accountId'])

print(accountList)
# Out:
# ['11657178', '78182213', '48350000', '43554718', '58345709', '51062315', '21227249', '96267302', '99840338', '93473112', '74852451', '06438135', '86294122', '17368524', '78241450', '20622824', '33616051', '03963282', '15515649', '25805684', '44080340', '02229174', '60618620', '13424970', '61304085', '17442826', '39869018', '87415815', '14379477', '43138218', '61495474', '91425624', '52030905', '43741051', '35357667', '08724660', '41663298', '94779396', '41781296', '35810319', '44391898', '04728732', '20954755', '43892675', '70539334', '35645176', '33925764', '59370771', '28404317', '82783948', '53785245']

# %%
import csv

# accountList = []
rows = []
data = response.json()

for x in data["Accounts"]:
    accountId = x["accountId"]
    phonenum = x["phoneNumber"]
    rows.append([accountId, phonenum])

# Write data to a CSV file
with open("accounts.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["accountId", "phoneNumber"])
    writer.writerows(rows)

print("Data has been written to accounts.csv")
# Out:
# Data has been written to accounts.csv

# %%
import csv

with open('accounts.csv', 'r') as file:
    csv_reader = csv.DictReader(file)
    data = list(csv_reader)
    
# df_list = list(df.index)
# print(df_list)

url_list = []
for row in data:
    accountid = row['accountId']
    url = ""
    url += "https://sandbox.capitalone.co.uk/developer-services-platform-pr/api/data/transactions/accounts/"
    url+= accountid
    url += "/create"
    url_list.append(url)
    # print(url);
# print(url_list)

for x, row in enumerate(data):
    row['url'] = url_list[x]

with open('accounts.csv', 'w', newline='') as file:
    fieldnames = data[0].keys()
    csv_writer = csv.DictWriter(file, fieldnames=fieldnames)

    csv_writer.writeheader()
    csv_writer.writerows(data)
